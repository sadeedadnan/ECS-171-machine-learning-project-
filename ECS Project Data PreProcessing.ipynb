# %%
# get rid of latitude/longtitude,

# %%
df = pd.read_csv('housing.csv')
df

#checking for na values

df.isna().sum()

#there are 207 null values in the total_bedrooms column. we need to delete those rows.
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df = df.dropna(how='any', axis=0)

df.isna().sum()
# no more na values
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
# checking datatype of each column

result = df.dtypes
print(result)

# ocean_proximity is categorical variable
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#df = pd.read_csv('housing.csv')

#auto_df_corr = auto_df.drop("origin", axis=1)
df.head()


fig, ax =  plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, center=0)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue="ocean_proximity")
